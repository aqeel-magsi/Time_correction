# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# ^^^ pyforest auto-imports - don't write above this line
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rc

mpl.rcParams['font.family'] = ['sans-serif']
mpl.rcParams['font.sans-serif'] = ['Helvetica']
tele_dir = "tele_event"
a=1 #rows
b=9 #columns
c=0
fig, axs = plt.subplots(nrows=3, ncols=2, figsize =(20,18), sharex=True,sharey=True)
custom_xlim = (0, 72)
custom_ylim = (-3, 3.2)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

# Setting the values for all axes.
plt.setp(axs, xlim=custom_xlim, ylim=custom_ylim)
for drift in sorted(os.listdir("tele_event")):
    #print(drift)
#     def last_4chars(x):
#         return(x[:18])
#     drift=sorted(drift, key = last_4chars)
    if drift.endswith(".csv"):
        ## Loop for each event
        drift_file = os.path.join(tele_dir,drift)
        print(drift_file)
        #grab last 4 characters of the file name:

        #print(drift_file)
        if os.path.isfile(drift_file):
            event_file = drift_file.rsplit("/",1)[1][:-9]
            year = drift_file.rsplit("/",1)[1][0:4]
            month = drift_file.rsplit("/",1)[1][4:6]
            day = drift_file.rsplit("/",1)[1][6:8]
            hour = drift_file.rsplit("/",1)[1][8:10]
            mint = drift_file.rsplit("/",1)[1][10:12]
            sec = drift_file.rsplit("/",1)[1][12:13]
            mag = drift_file.rsplit("/",1)[1][15:18]
            timee=(f"Event: {year}-{month}-{day} {hour}:{mint}:{sec}0")
        
            df=pd.read_csv(drift_file,sep="\t",header=None)
            df.columns=["no","drift","sta"]
            no=df['no']
            drift=df['drift']
            sta=df["sta"]
            #print(sta)
            axs=axs.ravel()
            axs[c].plot(no,drift,'o', color='b',label="Observed T",markersize=8)
            axs[c].set_title(f"{timee} M{mag}", fontsize=20)
            axs[c].set(facecolor = "floralwhite")
            axs[c].axhline(y=0, linewidth = 1.6,color='red',label="Ideal T")


            for i in range(len(sta)):
               if np.abs(drift[i])>0.4:
                    axs[c].text(i,drift[i]+0.05,sta[i], fontsize=18,color='red')
            c=c+1
axs[5].set_xlabel('No. of Stations', fontsize=22)
axs[4].set_xlabel('No. of Stations', fontsize=22)
#axs[0].legend(loc='best')
#axs[0].legend(loc='upper center', bbox_to_anchor=(0.5, 1.02),
 #         ncol=2, fancybox=True, shadow=True)
axs[2].set_ylabel('Time Drift (s)', fontsize=22)
# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.15, 
                    hspace=0.2)

# #fig inside
axs[0].annotate("(a)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax1.annotate("(ML32-31)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[1].annotate("(b)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax2.annotate("(ML66-68)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[2].annotate("(c)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax3.annotate("(ML41-42)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[3].annotate("(d)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax4.annotate("(ML64-65)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[4].annotate("(e)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax5.annotate("(K20-H36)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[5].annotate("(f)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax6.annotate("(K20-H36)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')




plt.savefig("Dense_Tele_Event.jpeg",dpi=380,bbox_inches='tight')
plt.savefig("Dense_Tele_Event.pdf")
plt.tight_layout()

plt.tight_layout()
plt.show()
        #print(sta)
#         plt.subplot(a,b,c)
#         plt.plot(df[sta],df[drift])
#         plt.title(tele_event)
#         c=c+1
# Out:
# tele_event/2020052323022_M5.6.csv
# tele_event/2020053018134_M5.6.csv
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# tele_event/2020060408493_M6.4.csv
# tele_event/2020060714365_M5.7.csv
# tele_event/2020060720063_M5.9.csv
# tele_event/2020060904561_M5.6.csv
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# ^^^ pyforest auto-imports - don't write above this line
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import rc

mpl.rcParams['font.family'] = ['sans-serif']
mpl.rcParams['font.sans-serif'] = ['Helvetica']
tele_dir = "tele_event" #folder contain csv files
a=1 #rows
b=9 #columns
c=0
fig, axs = plt.subplots(nrows=3, ncols=2, figsize =(20,18), sharex=True,sharey=True)
custom_xlim = (0, 72)
custom_ylim = (-3, 3.2)
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

# Setting the values for all axes.
plt.setp(axs, xlim=custom_xlim, ylim=custom_ylim)
for drift in sorted(os.listdir(tele_dir)):
    #print(drift)
#     def last_4chars(x):
#         return(x[:18])
#     drift=sorted(drift, key = last_4chars)
    if drift.endswith(".csv"):
        ## Loop for each event
        drift_file = os.path.join(tele_dir,drift)
        print(drift_file)
        #grab last 4 characters of the file name:

        #print(drift_file)
        if os.path.isfile(drift_file):
            event_file = drift_file.rsplit("/",1)[1][:-9]
            year = drift_file.rsplit("/",1)[1][0:4]
            month = drift_file.rsplit("/",1)[1][4:6]
            day = drift_file.rsplit("/",1)[1][6:8]
            hour = drift_file.rsplit("/",1)[1][8:10]
            mint = drift_file.rsplit("/",1)[1][10:12]
            sec = drift_file.rsplit("/",1)[1][12:13]
            mag = drift_file.rsplit("/",1)[1][15:18]
            timee=(f"Event: {year}-{month}-{day} {hour}:{mint}:{sec}0")
        
            df=pd.read_csv(drift_file,sep="\t",header=None)
            df.columns=["no","drift","sta"]
            no=df['no']
            drift=df['drift']
            sta=df["sta"]
            #print(sta)
            axs=axs.ravel()
            axs[c].plot(no,drift,'o', color='b',label="Observed T",markersize=8)
            axs[c].set_title(f"{timee} M{mag}", fontsize=20)
            axs[c].set(facecolor = "floralwhite")
            axs[c].axhline(y=0, linewidth = 1.6,color='red',label="Ideal T")


            for i in range(len(sta)):
               if np.abs(drift[i])>0.4:
                    axs[c].text(i,drift[i]+0.05,sta[i], fontsize=18,color='red')
            c=c+1
axs[5].set_xlabel('No. of Stations', fontsize=22)
axs[4].set_xlabel('No. of Stations', fontsize=22)
#axs[0].legend(loc='best')
#axs[0].legend(loc='upper center', bbox_to_anchor=(0.5, 1.02),
 #         ncol=2, fancybox=True, shadow=True)
axs[2].set_ylabel('Time Drift (s)', fontsize=22)
# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.15, 
                    hspace=0.2)

# #fig inside
axs[0].annotate("(a)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax1.annotate("(ML32-31)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[1].annotate("(b)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax2.annotate("(ML66-68)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[2].annotate("(c)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax3.annotate("(ML41-42)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[3].annotate("(d)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax4.annotate("(ML64-65)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[4].annotate("(e)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax5.annotate("(K20-H36)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')
axs[5].annotate("(f)", xy=(0.01, 0.03), xycoords="axes fraction",fontsize = 24.0)
#ax6.annotate("(K20-H36)", xy=(0.01, 0.93), xycoords="axes fraction", backgroundcolor='white')




plt.savefig("Dense_Tele_Event.jpeg",dpi=380,bbox_inches='tight')
plt.savefig("Dense_Tele_Event.pdf")
plt.tight_layout()

plt.tight_layout()
plt.show()
        #print(sta)
#         plt.subplot(a,b,c)
#         plt.plot(df[sta],df[drift])
#         plt.title(tele_event)
#         c=c+1
# Out:
# tele_event/2020052323022_M5.6.csv
# tele_event/2020053018134_M5.6.csv
# tele_event/2020060408493_M6.4.csv
# tele_event/2020060714365_M5.7.csv
# tele_event/2020060720063_M5.9.csv
# tele_event/2020060904561_M5.6.csv
